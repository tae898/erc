# %% [markdown]
# ## Let's see if the visual features extracted from `visual-features-extraction.ipynb` are okay
#
# Select a video from the training datset randomly

# %%
import yaml

with open('configs/paths.yaml', 'r') as stream:
    PATHS = yaml.safe_load(stream)

# %%
from glob import glob
import random

features_path = glob(os.path.join(PATHS['VISUAL_FEATURES']['train'], '*.npy'))

features_path = random.choice(features_path)

vid_path = os.path.join(PATHS['ORIGINAL_VIDEOS']['train'], os.path.basename(features_path)).replace('.npy', '.mp4')

assert os.path.isfile(vid_path)

import json

with open(PATHS['ANNOTATIONS']['all'], 'r') as stream:
    datasets = yaml.safe_load(stream)

annot = datasets['train'][os.path.basename(features_path).split('.npy')[0]]

# %% [markdown]
# Select a frame randomly and annotate it with the visual features.

# %%
import numpy as np
import av

features = np.load(features_path, allow_pickle=True)
# below line is necessary since the saved file is actually a dictionary.
features = features.item()

container = av.open(vid_path)

print(vid_path)

frames = {}
for idx, frame in enumerate(container.decode(video=0)):
    numpy_RGB = np.array(frame.to_image())
    frames[idx] = numpy_RGB

assert np.abs(len(frames) == len(features))

import matplotlib.pyplot as plt
import cv2

def draw_label(image, point, label, font=cv2.FONT_HERSHEY_SIMPLEX,
               font_scale=0.8, thickness=1):
    size = cv2.getTextSize(label, font, font_scale, thickness)[0]
    x, y = point
    cv2.rectangle(image, (x, y - size[1]), (x + size[0], y), (255, 0, 0), cv2.FILLED)
    cv2.putText(image, label, point, font, font_scale, (255, 255, 255), thickness, lineType=cv2.LINE_AA)

idx = random.choice(list(frames.keys()))
img = frames[idx]

feature = features[idx]

for feat in feature:
    bbox = feat['bbox']
    landmark = feat['landmark']
    age = feat['age']
    gender = feat['gender']
    embedding = feat['embedding']
    # face = feat['face']

    x1, y1, x2, y2, prob = bbox
    
    x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
    cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 0), 2)

    label = f"{str(round(prob*100, 1))} % face"
    draw_label(img, (x1, y2), label, font_scale=0.5, thickness=1)

    for lm in landmark:
        cv2.circle(img, (int(lm[0]), int(lm[1])), 1, (0,255,0), -1)

    label = f"{int(age)} years old, {str(round(gender*100, 1))} % female"
    draw_label(img, (x1, y1), label, font_scale=0.5, thickness=1)
    
plt.figure(figsize=(15,15))
plt.imshow(img)
plt.show()

for key, val in annot.items():
    print(key, '\t', val)
# Out:
# /home/tk/datasets/MELD/MELD.Raw/train/train_splits/dia243_utt0.mp4
# Dialogue_ID 	 243
# Emotion 	 joy
# EndTime 	 00:11:57,841
# Episode 	 24
# Season 	 1
# Sentiment 	 positive
# Speaker 	 Ross
# SrNo 	 2489
# StartTime 	 00:11:55,965
# Utterance 	 Ni-chou chi-ma!
# Utterance_ID 	 0
