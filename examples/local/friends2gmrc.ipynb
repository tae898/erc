# %% [markdown]
# # WIP

# %% [markdown]
# # load the packages
#
# Make sure that you installed the python package `grmc` from https://github.com/cltl/GRMCAnnotation

# %%
import os
from grmc.representation import annotation, container, entity, scenario, util
from cltl_face_all.face_alignment import FaceDetection
from cltl_face_all.arcface import ArcFace
from cltl_face_all.agegender import AgeGender

fd = FaceDetection(device='cpu', face_detector='sfd')
ag = AgeGender(device='cpu')
af = ArcFace(device='cpu')
# Out:
# [*] load ckpt from /home/tk/.virtualenvs/dev-python-3.7/lib/python3.7/site-packages/cltl_face_all/arcface/./pretrained_models/arc_res50/e_8_b_40000.ckpt

# %% [markdown]
# # Download small dataset and its annotation

# %%
os.makedirs('DEBUG', exist_ok=True)

# %cd DEBUG
# !wget https://raw.githubusercontent.com/declare-lab/MELD/master/data/MELD/train_sent_emo.csv
# !wget https://raw.githubusercontent.com/leolani/cltl-face-all/master/examples/smaller-datatsets-jsons/dataset-small.json
# !wget https://raw.githubusercontent.com/leolani/cltl-face-all/master/examples/smaller-datatsets-jsons/dataset-medium.json
# !wget https://raw.githubusercontent.com/leolani/cltl-face-all/master/examples/smaller-datatsets-jsons/dataset-large.json

# !gdown --id 1-2LeHC_5Cm2gWWT6vBrVhp8jorbjkN1_
# !unzip visual-features.zip
# !rm visual-features.zip

# !gdown --id 16ck7plW9v9eSHGCs5wuB2AhhufPRt3Wi
# !unzip smaller-dataset.zip
# !rm smaller-dataset.zip
# %cd ..
# Out:
# a576_utt0.mp4
#   inflating: smaller-dataset/dia576_utt1.mp4
#   inflating: smaller-dataset/dia576_utt2.mp4
#   inflating: smaller-dataset/dia576_utt3.mp4
#   inflating: smaller-dataset/dia576_utt4.mp4
#   inflating: smaller-dataset/dia576_utt5.mp4
#   inflating: smaller-dataset/dia576_utt6.mp4
#   inflating: smaller-dataset/dia576_utt7.mp4
#   inflating: smaller-dataset/dia576_utt8.mp4
#   inflating: smaller-dataset/dia576_utt9.mp4
#   inflating: smaller-dataset/dia576_utt10.mp4
#   inflating: smaller-dataset/dia577_utt0.mp4
#   inflating: smaller-dataset/dia577_utt1.mp4
#   inflating: smaller-dataset/dia577_utt2.mp4
#   inflating: smaller-dataset/dia577_utt3.mp4
#   inflating: smaller-dataset/dia577_utt4.mp4
#   inflating: smaller-dataset/dia577_utt5.mp4
#   inflating: smaller-dataset/dia577_utt6.mp4
#   inflating: smaller-dataset/dia577_utt7.mp4
#   inflating: smaller-dataset/dia585_utt0.mp4
#   inflating: smaller-dataset/dia585_utt1.mp4
#   inflating: smaller-dataset/dia585_utt2.mp4
#   inflating: smaller-dataset/dia585_utt3.mp4
#   inflating: smaller-dataset/dia585_utt4.mp4
#   inflating: smaller-dataset/dia585_utt5.mp4
#   inflating: smaller-dataset/dia585_utt6.mp4
#   inflating: smaller-dataset/dia585_utt7.mp4
#   inflating: smaller-dataset/dia585_utt8.mp4
#   inflating: smaller-dataset/dia585_utt9.mp4
#   inflating: smaller-dataset/dia585_utt10.mp4
#   inflating: smaller-dataset/dia585_utt11.mp4
#   inflating: smaller-dataset/dia585_utt12.mp4
#   inflating: smaller-dataset/dia591_utt0.mp4
#   inflating: smaller-dataset/dia591_utt1.mp4
#   inflating: smaller-dataset/dia591_utt2.mp4
#   inflating: smaller-dataset/dia591_utt3.mp4
#   inflating: smaller-dataset/dia596_utt0.mp4
#   inflating: smaller-dataset/dia596_utt1.mp4
#   inflating: smaller-dataset/dia596_utt2.mp4
#   inflating: smaller-dataset/dia596_utt3.mp4
#   inflating: smaller-dataset/dia596_utt4.mp4
#   inflating: smaller-dataset/dia596_utt5.mp4
#   inflating: smaller-dataset/dia596_utt6.mp4
#   inflating: smaller-dataset/dia596_utt7.mp4
#   inflating: smaller-dataset/dia596_utt8.mp4
#   inflating: smaller-dataset/dia596_utt9.mp4
#   inflating: smaller-dataset/dia596_utt10.mp4
#   inflating: smaller-dataset/dia596_utt11.mp4
#   inflating: smaller-dataset/dia596_utt12.mp4
#   inflating: smaller-dataset/dia596_utt13.mp4
#   inflating: smaller-dataset/dia596_utt14.mp4
#   inflating: smaller-dataset/dia596_utt15.mp4
#   inflating: smaller-dataset/dia596_utt16.mp4
#   inflating: smaller-dataset/dia596_utt17.mp4
#   inflating: smaller-dataset/dia596_utt18.mp4
#   inflating: smaller-dataset/dia596_utt19.mp4
#   inflating: smaller-dataset/dia596_utt20.mp4
#   inflating: smaller-dataset/dia596_utt21.mp4
#   inflating: smaller-dataset/dia610_utt0.mp4
#   inflating: smaller-dataset/dia610_utt1.mp4
#   inflating: smaller-dataset/dia610_utt2.mp4
#   inflating: smaller-dataset/dia610_utt3.mp4
#   inflating: smaller-dataset/dia610_utt4.mp4
#   inflating: smaller-dataset/dia610_utt5.mp4
#   inflating: smaller-dataset/dia610_utt6.mp4
#   inflating: smaller-dataset/dia610_utt7.mp4
#   inflating: smaller-dataset/dia617_utt0.mp4
#   inflating: smaller-dataset/dia617_utt1.mp4
#   inflating: smaller-dataset/dia617_utt2.mp4
#   inflating: smaller-dataset/dia617_utt3.mp4
#   inflating: smaller-dataset/dia617_utt4.mp4
#   inflating: smaller-dataset/dia617_utt5.mp4
#   inflating: smaller-dataset/dia617_utt6.mp4
#   inflating: smaller-dataset/dia617_utt7.mp4
#   inflating: smaller-dataset/dia617_utt8.mp4
#   inflating: smaller-dataset/dia617_utt9.mp4
#   inflating: smaller-dataset/dia617_utt10.mp4
#   inflating: smaller-dataset/dia631_utt0.mp4
#   inflating: smaller-dataset/dia652_utt0.mp4
#   inflating: smaller-dataset/dia652_utt1.mp4
#   inflating: smaller-dataset/dia652_utt2.mp4
#   inflating: smaller-dataset/dia652_utt3.mp4
#   inflating: smaller-dataset/dia652_utt4.mp4
#   inflating: smaller-dataset/dia652_utt5.mp4
#   inflating: smaller-dataset/dia652_utt6.mp4
#   inflating: smaller-dataset/dia652_utt7.mp4
#   inflating: smaller-dataset/dia652_utt8.mp4
#   inflating: smaller-dataset/dia652_utt9.mp4
#   inflating: smaller-dataset/dia652_utt10.mp4
#   inflating: smaller-dataset/dia652_utt11.mp4
#   inflating: smaller-dataset/dia652_utt12.mp4
#   inflating: smaller-dataset/dia652_utt13.mp4
#   inflating: smaller-dataset/dia652_utt14.mp4
#   inflating: smaller-dataset/dia652_utt15.mp4
#   inflating: smaller-dataset/dia668_utt0.mp4
#   inflating: smaller-dataset/dia668_utt1.mp4
#   inflating: smaller-dataset/dia689_utt0.mp4
#   inflating: smaller-dataset/dia689_utt1.mp4
#   inflating: smaller-dataset/dia689_utt2.mp4
#   inflating: smaller-dataset/dia689_utt3.mp4
#   inflating: smaller-dataset/dia689_utt4.mp4
#   inflating: smaller-dataset/dia689_utt5.mp4
#   inflating: smaller-dataset/dia689_utt6.mp4
#   inflating: smaller-dataset/dia689_utt7.mp4
#   inflating: smaller-dataset/dia689_utt8.mp4
#   inflating: smaller-dataset/dia689_utt9.mp4
#   inflating: smaller-dataset/dia689_utt10.mp4
#   inflating: smaller-dataset/dia689_utt11.mp4
#   inflating: smaller-dataset/dia689_utt12.mp4
#   inflating: smaller-dataset/dia689_utt13.mp4
#   inflating: smaller-dataset/dia689_utt14.mp4
#   inflating: smaller-dataset/dia698_utt0.mp4
#   inflating: smaller-dataset/dia698_utt1.mp4
#   inflating: smaller-dataset/dia698_utt2.mp4
#   inflating: smaller-dataset/dia698_utt3.mp4
#   inflating: smaller-dataset/dia698_utt4.mp4
#   inflating: smaller-dataset/dia698_utt5.mp4
#   inflating: smaller-dataset/dia698_utt6.mp4
#   inflating: smaller-dataset/dia698_utt7.mp4
#   inflating: smaller-dataset/dia713_utt0.mp4
#   inflating: smaller-dataset/dia713_utt1.mp4
#   inflating: smaller-dataset/dia713_utt2.mp4
#   inflating: smaller-dataset/dia725_utt0.mp4
#   inflating: smaller-dataset/dia725_utt1.mp4
#   inflating: smaller-dataset/dia725_utt2.mp4
#   inflating: smaller-dataset/dia725_utt3.mp4
#   inflating: smaller-dataset/dia725_utt4.mp4
#   inflating: smaller-dataset/dia725_utt5.mp4
#   inflating: smaller-dataset/dia725_utt6.mp4
#   inflating: smaller-dataset/dia733_utt0.mp4
#   inflating: smaller-dataset/dia733_utt1.mp4
#   inflating: smaller-dataset/dia733_utt2.mp4
#   inflating: smaller-dataset/dia733_utt3.mp4
#   inflating: smaller-dataset/dia733_utt4.mp4
#   inflating: smaller-dataset/dia733_utt5.mp4
#   inflating: smaller-dataset/dia733_utt6.mp4
#   inflating: smaller-dataset/dia733_utt7.mp4
#   inflating: smaller-dataset/dia733_utt8.mp4
#   inflating: smaller-dataset/dia733_utt9.mp4
#   inflating: smaller-dataset/dia733_utt10.mp4
#   inflating: smaller-dataset/dia733_utt11.mp4
#   inflating: smaller-dataset/dia733_utt12.mp4
#   inflating: smaller-dataset/dia738_utt0.mp4
#   inflating: smaller-dataset/dia738_utt1.mp4
#   inflating: smaller-dataset/dia738_utt2.mp4
#   inflating: smaller-dataset/dia738_utt3.mp4
#   inflating: smaller-dataset/dia738_utt4.mp4
#   inflating: smaller-dataset/dia738_utt5.mp4
#   inflating: smaller-dataset/dia738_utt6.mp4
#   inflating: smaller-dataset/dia738_utt7.mp4
#   inflating: smaller-dataset/dia738_utt8.mp4
#   inflating: smaller-dataset/dia765_utt0.mp4
#   inflating: smaller-dataset/dia765_utt1.mp4
#   inflating: smaller-dataset/dia767_utt0.mp4
#   inflating: smaller-dataset/dia767_utt1.mp4
#   inflating: smaller-dataset/dia767_utt2.mp4
#   inflating: smaller-dataset/dia767_utt3.mp4
#   inflating: smaller-dataset/dia767_utt4.mp4
#   inflating: smaller-dataset/dia767_utt5.mp4
#   inflating: smaller-dataset/dia767_utt6.mp4
#   inflating: smaller-dataset/dia767_utt7.mp4
#   inflating: smaller-dataset/dia767_utt8.mp4
#   inflating: smaller-dataset/dia767_utt9.mp4
#   inflating: smaller-dataset/dia767_utt10.mp4
#   inflating: smaller-dataset/dia767_utt11.mp4
#   inflating: smaller-dataset/dia773_utt0.mp4
#   inflating: smaller-dataset/dia773_utt1.mp4
#   inflating: smaller-dataset/dia773_utt2.mp4
#   inflating: smaller-dataset/dia778_utt0.mp4
#   inflating: smaller-dataset/dia778_utt1.mp4
#   inflating: smaller-dataset/dia778_utt2.mp4
#   inflating: smaller-dataset/dia778_utt3.mp4
#   inflating: smaller-dataset/dia778_utt4.mp4
#   inflating: smaller-dataset/dia778_utt5.mp4
#   inflating: smaller-dataset/dia778_utt6.mp4
#   inflating: smaller-dataset/dia778_utt7.mp4
#   inflating: smaller-dataset/dia778_utt8.mp4
#   inflating: smaller-dataset/dia778_utt9.mp4
#   inflating: smaller-dataset/dia778_utt10.mp4
#   inflating: smaller-dataset/dia802_utt0.mp4
#   inflating: smaller-dataset/dia802_utt1.mp4
#   inflating: smaller-dataset/dia802_utt2.mp4
#   inflating: smaller-dataset/dia802_utt3.mp4
#   inflating: smaller-dataset/dia802_utt4.mp4
#   inflating: smaller-dataset/dia805_utt0.mp4
#   inflating: smaller-dataset/dia805_utt1.mp4
#   inflating: smaller-dataset/dia805_utt2.mp4
#   inflating: smaller-dataset/dia805_utt3.mp4
#   inflating: smaller-dataset/dia805_utt4.mp4
#   inflating: smaller-dataset/dia805_utt5.mp4
#   inflating: smaller-dataset/dia805_utt6.mp4
#   inflating: smaller-dataset/dia805_utt7.mp4
#   inflating: smaller-dataset/dia834_utt0.mp4
#   inflating: smaller-dataset/dia834_utt1.mp4
#   inflating: smaller-dataset/dia834_utt2.mp4
#   inflating: smaller-dataset/dia834_utt3.mp4
#   inflating: smaller-dataset/dia834_utt4.mp4
#   inflating: smaller-dataset/dia834_utt5.mp4
#   inflating: smaller-dataset/dia834_utt6.mp4
#   inflating: smaller-dataset/dia834_utt7.mp4
#   inflating: smaller-dataset/dia834_utt8.mp4
#   inflating: smaller-dataset/dia834_utt9.mp4
#   inflating: smaller-dataset/dia834_utt10.mp4
#   inflating: smaller-dataset/dia834_utt11.mp4
#   inflating: smaller-dataset/dia834_utt12.mp4
#   inflating: smaller-dataset/dia834_utt13.mp4
#   inflating: smaller-dataset/dia834_utt14.mp4
#   inflating: smaller-dataset/dia834_utt15.mp4
#   inflating: smaller-dataset/dia851_utt0.mp4
#   inflating: smaller-dataset/dia851_utt1.mp4
#   inflating: smaller-dataset/dia851_utt2.mp4
#   inflating: smaller-dataset/dia851_utt3.mp4
#   inflating: smaller-dataset/dia851_utt4.mp4
#   inflating: smaller-dataset/dia851_utt5.mp4
#   inflating: smaller-dataset/dia851_utt6.mp4
#   inflating: smaller-dataset/dia851_utt7.mp4
#   inflating: smaller-dataset/dia851_utt8.mp4
#   inflating: smaller-dataset/dia851_utt9.mp4
#   inflating: smaller-dataset/dia851_utt10.mp4
#   inflating: smaller-dataset/dia851_utt11.mp4
#   inflating: smaller-dataset/dia851_utt12.mp4
#   inflating: smaller-dataset/dia851_utt13.mp4
#   inflating: smaller-dataset/dia851_utt14.mp4
#   inflating: smaller-dataset/dia851_utt15.mp4
#   inflating: smaller-dataset/dia851_utt16.mp4
#   inflating: smaller-dataset/dia851_utt17.mp4
#   inflating: smaller-dataset/dia851_utt18.mp4
#   inflating: smaller-dataset/dia851_utt19.mp4
#   inflating: smaller-dataset/dia851_utt20.mp4
#   inflating: smaller-dataset/dia869_utt0.mp4
#   inflating: smaller-dataset/dia869_utt1.mp4
#   inflating: smaller-dataset/dia869_utt2.mp4
#   inflating: smaller-dataset/dia869_utt3.mp4
#   inflating: smaller-dataset/dia869_utt4.mp4
#   inflating: smaller-dataset/dia869_utt5.mp4
#   inflating: smaller-dataset/dia869_utt6.mp4
#   inflating: smaller-dataset/dia869_utt7.mp4
#   inflating: smaller-dataset/dia869_utt8.mp4
#   inflating: smaller-dataset/dia869_utt9.mp4
#   inflating: smaller-dataset/dia869_utt10.mp4
#   inflating: smaller-dataset/dia869_utt11.mp4
#   inflating: smaller-dataset/dia869_utt12.mp4
#   inflating: smaller-dataset/dia869_utt13.mp4
#   inflating: smaller-dataset/dia869_utt14.mp4
#   inflating: smaller-dataset/dia869_utt15.mp4
#   inflating: smaller-dataset/dia869_utt16.mp4
#   inflating: smaller-dataset/dia869_utt17.mp4
#   inflating: smaller-dataset/dia890_utt0.mp4
#   inflating: smaller-dataset/dia890_utt1.mp4
#   inflating: smaller-dataset/dia890_utt2.mp4
#   inflating: smaller-dataset/dia890_utt3.mp4
#   inflating: smaller-dataset/dia890_utt4.mp4
#   inflating: smaller-dataset/dia900_utt0.mp4
#   inflating: smaller-dataset/dia900_utt1.mp4
#   inflating: smaller-dataset/dia900_utt2.mp4
#   inflating: smaller-dataset/dia900_utt3.mp4
#   inflating: smaller-dataset/dia900_utt4.mp4
#   inflating: smaller-dataset/dia900_utt5.mp4
#   inflating: smaller-dataset/dia900_utt6.mp4
#   inflating: smaller-dataset/dia900_utt7.mp4
#   inflating: smaller-dataset/dia900_utt8.mp4
#   inflating: smaller-dataset/dia900_utt9.mp4
#   inflating: smaller-dataset/dia900_utt10.mp4
#   inflating: smaller-dataset/dia900_utt11.mp4
#   inflating: smaller-dataset/dia900_utt12.mp4
#   inflating: smaller-dataset/dia900_utt13.mp4
#   inflating: smaller-dataset/dia900_utt14.mp4
#   inflating: smaller-dataset/dia900_utt15.mp4
#   inflating: smaller-dataset/dia903_utt0.mp4
#   inflating: smaller-dataset/dia903_utt1.mp4
#   inflating: smaller-dataset/dia903_utt2.mp4
#   inflating: smaller-dataset/dia904_utt0.mp4
#   inflating: smaller-dataset/dia904_utt1.mp4
#   inflating: smaller-dataset/dia904_utt2.mp4
#   inflating: smaller-dataset/dia904_utt3.mp4
#   inflating: smaller-dataset/dia904_utt4.mp4
#   inflating: smaller-dataset/dia904_utt5.mp4
#   inflating: smaller-dataset/dia904_utt6.mp4
#   inflating: smaller-dataset/dia904_utt7.mp4
#   inflating: smaller-dataset/dia919_utt0.mp4
#   inflating: smaller-dataset/dia919_utt1.mp4
#   inflating: smaller-dataset/dia939_utt0.mp4
#   inflating: smaller-dataset/dia939_utt1.mp4
#   inflating: smaller-dataset/dia939_utt2.mp4
#   inflating: smaller-dataset/dia939_utt3.mp4
#   inflating: smaller-dataset/dia939_utt4.mp4
#   inflating: smaller-dataset/dia939_utt5.mp4
#   inflating: smaller-dataset/dia939_utt6.mp4
#   inflating: smaller-dataset/dia939_utt7.mp4
#   inflating: smaller-dataset/dia939_utt8.mp4
#   inflating: smaller-dataset/dia939_utt9.mp4
#   inflating: smaller-dataset/dia939_utt10.mp4
#   inflating: smaller-dataset/dia939_utt11.mp4
#   inflating: smaller-dataset/dia939_utt12.mp4
#   inflating: smaller-dataset/dia939_utt13.mp4
#   inflating: smaller-dataset/dia939_utt14.mp4
#   inflating: smaller-dataset/dia939_utt15.mp4
#   inflating: smaller-dataset/dia939_utt16.mp4
#   inflating: smaller-dataset/dia939_utt17.mp4
#   inflating: smaller-dataset/dia939_utt18.mp4
#   inflating: smaller-dataset/dia939_utt19.mp4
#   inflating: smaller-dataset/dia939_utt20.mp4
#   inflating: smaller-dataset/dia961_utt0.mp4
#   inflating: smaller-dataset/dia961_utt1.mp4
#   inflating: smaller-dataset/dia961_utt2.mp4
#   inflating: smaller-dataset/dia961_utt3.mp4
#   inflating: smaller-dataset/dia961_utt4.mp4
#   inflating: smaller-dataset/dia961_utt5.mp4
#   inflating: smaller-dataset/dia961_utt6.mp4
#   inflating: smaller-dataset/dia961_utt7.mp4
#   inflating: smaller-dataset/dia961_utt8.mp4
#   inflating: smaller-dataset/dia961_utt9.mp4
#   inflating: smaller-dataset/dia961_utt10.mp4
#   inflating: smaller-dataset/dia961_utt11.mp4
#   inflating: smaller-dataset/dia961_utt12.mp4
#   inflating: smaller-dataset/dia961_utt13.mp4
#   inflating: smaller-dataset/dia961_utt14.mp4
#   inflating: smaller-dataset/dia964_utt0.mp4
#   inflating: smaller-dataset/dia964_utt1.mp4
#   inflating: smaller-dataset/dia964_utt2.mp4
#   inflating: smaller-dataset/dia964_utt3.mp4
#   inflating: smaller-dataset/dia964_utt4.mp4
#   inflating: smaller-dataset/dia964_utt5.mp4
#   inflating: smaller-dataset/dia964_utt6.mp4
#   inflating: smaller-dataset/dia964_utt7.mp4
#   inflating: smaller-dataset/dia964_utt8.mp4
#   inflating: smaller-dataset/dia964_utt9.mp4
#   inflating: smaller-dataset/dia964_utt10.mp4
#   inflating: smaller-dataset/dia964_utt11.mp4
#   inflating: smaller-dataset/dia964_utt12.mp4
#   inflating: smaller-dataset/dia964_utt13.mp4
#   inflating: smaller-dataset/dia964_utt14.mp4
#   inflating: smaller-dataset/dia964_utt15.mp4
#   inflating: smaller-dataset/dia964_utt16.mp4
#   inflating: smaller-dataset/dia964_utt17.mp4
#   inflating: smaller-dataset/dia982_utt0.mp4
#   inflating: smaller-dataset/dia982_utt1.mp4
#   inflating: smaller-dataset/dia982_utt2.mp4
#   inflating: smaller-dataset/dia982_utt3.mp4
#   inflating: smaller-dataset/dia982_utt4.mp4
#   inflating: smaller-dataset/dia982_utt5.mp4
#   inflating: smaller-dataset/dia982_utt6.mp4
#   inflating: smaller-dataset/dia982_utt7.mp4
#   inflating: smaller-dataset/dia982_utt8.mp4
#   inflating: smaller-dataset/dia982_utt9.mp4
#   inflating: smaller-dataset/dia982_utt10.mp4
#   inflating: smaller-dataset/dia986_utt0.mp4
#   inflating: smaller-dataset/dia986_utt1.mp4
#   inflating: smaller-dataset/dia986_utt2.mp4
#   inflating: smaller-dataset/dia986_utt3.mp4
#   inflating: smaller-dataset/dia986_utt4.mp4
#   inflating: smaller-dataset/dia986_utt5.mp4
#   inflating: smaller-dataset/dia986_utt6.mp4
#   inflating: smaller-dataset/dia986_utt7.mp4
#   inflating: smaller-dataset/dia986_utt8.mp4
#   inflating: smaller-dataset/dia986_utt9.mp4
#   inflating: smaller-dataset/dia986_utt10.mp4
#   inflating: smaller-dataset/dia986_utt11.mp4
#   inflating: smaller-dataset/dia986_utt12.mp4
#   inflating: smaller-dataset/dia986_utt13.mp4
#   inflating: smaller-dataset/dia986_utt14.mp4
#   inflating: smaller-dataset/dia986_utt15.mp4
#   inflating: smaller-dataset/dia986_utt16.mp4
#   inflating: smaller-dataset/dia990_utt0.mp4
#   inflating: smaller-dataset/dia990_utt1.mp4
#   inflating: smaller-dataset/dia990_utt2.mp4
#   inflating: smaller-dataset/dia990_utt3.mp4
#   inflating: smaller-dataset/dia990_utt4.mp4
#   inflating: smaller-dataset/dia990_utt5.mp4
#   inflating: smaller-dataset/dia990_utt6.mp4
#   inflating: smaller-dataset/dia990_utt7.mp4
#   inflating: smaller-dataset/dia990_utt8.mp4
#   inflating: smaller-dataset/dia990_utt9.mp4
#   inflating: smaller-dataset/dia990_utt10.mp4
#   inflating: smaller-dataset/dia990_utt11.mp4
#   inflating: smaller-dataset/dia990_utt12.mp4
#   inflating: smaller-dataset/dia990_utt13.mp4
#   inflating: smaller-dataset/dia990_utt14.mp4
#   inflating: smaller-dataset/dia990_utt15.mp4
#   inflating: smaller-dataset/dia990_utt16.mp4
#   inflating: smaller-dataset/dia990_utt17.mp4
#   inflating: smaller-dataset/dia990_utt18.mp4
#   inflating: smaller-dataset/dia990_utt19.mp4
#   inflating: smaller-dataset/dia993_utt0.mp4
#   inflating: smaller-dataset/dia993_utt1.mp4
#   inflating: smaller-dataset/dia993_utt2.mp4
#   inflating: smaller-dataset/dia993_utt3.mp4
#   inflating: smaller-dataset/dia1000_utt0.mp4
#   inflating: smaller-dataset/dia1000_utt1.mp4
#   inflating: smaller-dataset/dia1000_utt2.mp4
#   inflating: smaller-dataset/dia1000_utt3.mp4
#   inflating: smaller-dataset/dia1007_utt0.mp4
#   inflating: smaller-dataset/dia1007_utt1.mp4
#   inflating: smaller-dataset/dia1007_utt2.mp4
#   inflating: smaller-dataset/dia1007_utt3.mp4
#   inflating: smaller-dataset/dia1007_utt4.mp4
#   inflating: smaller-dataset/dia1007_utt5.mp4
#   inflating: smaller-dataset/dia1007_utt6.mp4
#   inflating: smaller-dataset/dia1007_utt7.mp4
#   inflating: smaller-dataset/dia1007_utt8.mp4
#   inflating: smaller-dataset/dia1007_utt9.mp4
#   inflating: smaller-dataset/dia1007_utt10.mp4
#   inflating: smaller-dataset/dia1007_utt11.mp4
#   inflating: smaller-dataset/dia1007_utt12.mp4
#   inflating: smaller-dataset/dia1007_utt13.mp4
#   inflating: smaller-dataset/dia1007_utt14.mp4
#   inflating: smaller-dataset/dia1007_utt15.mp4
#   inflating: smaller-dataset/dia1029_utt0.mp4
#   inflating: smaller-dataset/dia1029_utt1.mp4
#   inflating: smaller-dataset/dia1029_utt2.mp4
#   inflating: smaller-dataset/dia1029_utt3.mp4
#   inflating: smaller-dataset/dia1029_utt4.mp4
#   inflating: smaller-dataset/dia1029_utt5.mp4
#   inflating: smaller-dataset/dia1029_utt6.mp4
#   inflating: smaller-dataset/dia1029_utt7.mp4
#   inflating: smaller-dataset/dia1029_utt8.mp4
#   inflating: smaller-dataset/dia1029_utt9.mp4
#   inflating: smaller-dataset/dia1029_utt10.mp4
#   inflating: smaller-dataset/dia1029_utt11.mp4
#   inflating: smaller-dataset/dia1029_utt12.mp4
#   inflating: smaller-dataset/dia1029_utt13.mp4
#   inflating: smaller-dataset/dia1029_utt14.mp4
# /home/tk/repos/cltl-face-all/examples/local

# %% [markdown]
# # Simplify the data. After this cell the dict obj `datasets` will have all you need

# %%
import os
from glob import glob
import csv
import json


# Only the train_sent_emo is relevant to us since the smaller datasets
# are subset of the original train dataset.
annotation_path = 'data/train_sent_emo.csv'
        
VIDS_DIR = "data/smaller-dataset/"

datasets_ = {}
datasets_['small'] = "data/dataset-small.json"
datasets_['medium'] = "data/dataset-medium.json"
datasets_['large'] = "data/dataset-large.json"

for datasize in ['small', 'medium', 'large']:
    with open(datasets_[datasize], 'r') as stream:
        datasets_[datasize] = json.load(stream)

with open(annotation_path) as f:
    reader = csv.reader(f)
    annotations = list(reader)


# See if we have all of the videos
for datasize in ['small', 'medium', 'large']:
    for datatype in ['train', 'dev', 'test']:
        diautt_ = datasets_[datasize][datatype]
        for diautt in diautt_:
            assert os.path.isfile(os.path.join(VIDS_DIR, diautt))

# Find the corresponding speaker / emotion / sentiment from the annotations

diautt2anno = {}
for row in annotations[1:]:
    SrNo, Utterance, Speaker, Emotion, Sentiment, Dialogue_ID,\
        Utterance_ID, Season, Episode, StartTime, EndTime = row

    if f"dia{Dialogue_ID}_utt{Utterance_ID}.mp4" not in str(os.listdir(os.path.join(VIDS_DIR))):
        continue
    
    diautt2anno[f"dia{Dialogue_ID}_utt{Utterance_ID}"] = \
        {'SrNo': SrNo, 
        'Utterance': Utterance, 
        'Speaker': Speaker, 
        'Emotion': Emotion, 
        'Sentiment': Sentiment, 
        'Dialogue_ID': Dialogue_ID,
        'Utterance_ID': Utterance_ID, 
        'Season': Season, 
        'Episode': Episode, 
        'StartTime': StartTime, 
        'EndTime':EndTime}


datasets = {}
for DATASIZE in ['small', 'medium', 'large']:
    datasets[DATASIZE] = {}
    for DATATYPE in ['train', 'dev', 'test']:
        datasets[DATASIZE][DATATYPE] = {}
        diautt_ = datasets_[DATASIZE][DATATYPE]
        for diautt in diautt_:
            diautt_without_mp4 = diautt.split('.mp4')[0]
            datasets[DATASIZE][DATATYPE][diautt_without_mp4] = diautt2anno[diautt_without_mp4]

# %% [markdown]
# Let's see what `datasets` has

# %%
diautt_chosen = 'dia1000_utt0'

datasets['small']['train'][diautt_chosen]
# Out:
# {'SrNo': '10029',
#  'Utterance': 'Would you look at this dump? He hated us. This is his final revenge!',
#  'Speaker': 'Monica',
#  'Emotion': 'disgust',
#  'Sentiment': 'negative',
#  'Dialogue_ID': '1000',
#  'Utterance_ID': '0',
#  'Season': '2',
#  'Episode': '3',
#  'StartTime': '00:06:45,780',
#  'EndTime': '00:06:49,783'}

# %% [markdown]
# Load the video and get the visual features

# %%
import av
import numpy as np
from tqdm.notebook import tqdm

VIDPATH = os.path.join(VIDS_DIR, f'{diautt_chosen}.mp4')
container = av.open(VIDPATH)

visual_features = {}
for frame in tqdm(container.decode(video=0)):
    idx = frame.index
    visual_features[idx] = []
    numpy_RGB = np.array(frame.to_image())
    batch = numpy_RGB[np.newaxis, ...]
    bboxes = fd.detect_faces(batch)
    print(f"number of faces detected in the frame {idx} is {len(bboxes[0])}")

    if len(bboxes[0]) == 0:
        continue

    landmarks = fd.detect_landmarks(batch, bboxes)

    faces = fd.crop_and_align(batch, bboxes, landmarks)
    faces = np.concatenate(faces, axis=0)
    embeddings = af.predict(faces)
    ages, genders = ag.predict(faces)

    # print(len(bboxes[0]), len(landmarks[0]), len(ages), len(genders), len(embeddings), len(faces))
    for bb, lm, a, g, emb in zip(bboxes[0], landmarks[0], ages, genders, embeddings):
        x1, y1, x2, y2, prob = bb

        to_append = {'bbox': bb, 
                    'landmark': lm, 
                    'age': a,
                    'gender': g,
                    'embedding': emb}

        visual_features[idx].append(to_append)
    # print(len(visual_features), idx+1)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# number of faces detected in the frame 0 is 3
# number of faces detected in the frame 1 is 3
# number of faces detected in the frame 2 is 3
# number of faces detected in the frame 3 is 3
# number of faces detected in the frame 4 is 2
# number of faces detected in the frame 5 is 2
# number of faces detected in the frame 6 is 2
# number of faces detected in the frame 7 is 2
# number of faces detected in the frame 8 is 2
# number of faces detected in the frame 9 is 3
# number of faces detected in the frame 10 is 3
# number of faces detected in the frame 11 is 3
# number of faces detected in the frame 12 is 3
# number of faces detected in the frame 13 is 3
# number of faces detected in the frame 14 is 3
# number of faces detected in the frame 15 is 3
# number of faces detected in the frame 16 is 3
# number of faces detected in the frame 17 is 3
# number of faces detected in the frame 18 is 3
# number of faces detected in the frame 19 is 3
# number of faces detected in the frame 20 is 3
# number of faces detected in the frame 21 is 3
# number of faces detected in the frame 22 is 3
# number of faces detected in the frame 23 is 4
# number of faces detected in the frame 24 is 3
# number of faces detected in the frame 25 is 4
# number of faces detected in the frame 26 is 4
# number of faces detected in the frame 27 is 5
# number of faces detected in the frame 28 is 5
# number of faces detected in the frame 29 is 5
# number of faces detected in the frame 30 is 5
# number of faces detected in the frame 31 is 4
# number of faces detected in the frame 32 is 6
# number of faces detected in the frame 33 is 6
# number of faces detected in the frame 34 is 6
# number of faces detected in the frame 35 is 6
# number of faces detected in the frame 36 is 6
# number of faces detected in the frame 37 is 6
# number of faces detected in the frame 38 is 6
# number of faces detected in the frame 39 is 6
# number of faces detected in the frame 40 is 6
# number of faces detected in the frame 41 is 5
# number of faces detected in the frame 42 is 5
# number of faces detected in the frame 43 is 6
# number of faces detected in the frame 44 is 5
# number of faces detected in the frame 45 is 5
# number of faces detected in the frame 46 is 5
# number of faces detected in the frame 47 is 5
# number of faces detected in the frame 48 is 4
# number of faces detected in the frame 49 is 4
# number of faces detected in the frame 50 is 6
# number of faces detected in the frame 51 is 6
# number of faces detected in the frame 52 is 6
# number of faces detected in the frame 53 is 6
# number of faces detected in the frame 54 is 6
# number of faces detected in the frame 55 is 6
# number of faces detected in the frame 56 is 6
# number of faces detected in the frame 57 is 6
# number of faces detected in the frame 58 is 6
# number of faces detected in the frame 59 is 6
# number of faces detected in the frame 60 is 6
# number of faces detected in the frame 61 is 5
# number of faces detected in the frame 62 is 5
# number of faces detected in the frame 63 is 5
# number of faces detected in the frame 64 is 5
# number of faces detected in the frame 65 is 5
# number of faces detected in the frame 66 is 5
# number of faces detected in the frame 67 is 4
# number of faces detected in the frame 68 is 4
# number of faces detected in the frame 69 is 4
# number of faces detected in the frame 70 is 4
# number of faces detected in the frame 71 is 4
# number of faces detected in the frame 72 is 4
# number of faces detected in the frame 73 is 4
# number of faces detected in the frame 74 is 4
# number of faces detected in the frame 75 is 4
# number of faces detected in the frame 76 is 5
# number of faces detected in the frame 77 is 5
# number of faces detected in the frame 78 is 5
# number of faces detected in the frame 79 is 5
# number of faces detected in the frame 80 is 5
# number of faces detected in the frame 81 is 5
# number of faces detected in the frame 82 is 5
# number of faces detected in the frame 83 is 5
# number of faces detected in the frame 84 is 4
# number of faces detected in the frame 85 is 4
# number of faces detected in the frame 86 is 4
# number of faces detected in the frame 87 is 4
# number of faces detected in the frame 88 is 4
# number of faces detected in the frame 89 is 3
# number of faces detected in the frame 90 is 3
# number of faces detected in the frame 91 is 2
# number of faces detected in the frame 92 is 2
# number of faces detected in the frame 93 is 3
# number of faces detected in the frame 95 is 2
# number of faces detected in the frame 95 is 4

# %% [markdown]
# Let's take a look at the visual features

# %%
# The frame number 0, and detection number 0 has 5 attributes (bbox, landmark, age, gender, and embedding)
visual_features[0][0].keys()
# Out:
# dict_keys(['bbox', 'landmark', 'age', 'gender', 'embedding'])

# %% [markdown]
# # TODOs:
#
# 1. match the face to the speaker if possible (Tae's working on the face recognition of the friends characters.)
#
# 2. Save the visual features in the grmc format
#
# 3. etc.
