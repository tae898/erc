# %%
# !nvidia-smi
# Out:
# Mon Feb 22 15:22:44 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.102.04   Driver Version: 450.102.04   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1050    Off  | 00000000:01:00.0 Off |                  N/A |
# | N/A   55C    P0    N/A /  N/A |   1029MiB /  4042MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1278      G   /usr/lib/xorg/Xorg                 80MiB |
# |    0   N/A  N/A      2030      G   /usr/lib/xorg/Xorg                245MiB |
# |    0   N/A  N/A      2203      G   /usr/bin/gnome-shell              207MiB |
# |    0   N/A  N/A      3534      G   ...AAAAAAAAA= --shared-files      249MiB |
# |    0   N/A  N/A      8325      G   ...AAAAAAAAA= --shared-files       34MiB |
# |    0   N/A  N/A     76458      G   ...AAAAAAAA== --shared-files      202MiB |
# +-----------------------------------------------------------------------------+

# %%
# import timm
# from pprint import pprint
# model_names = timm.list_models(pretrained=True)
# pprint(model_names)

# %%
# !python3 train.py --config configs/audio_effnet.yaml --gpus 0
# Out:
# { 'dataset': { 'train': { 'args': { 'csv_path': 'data/AFEW/raw-audios/train.csv',
#                                     'data_dir': 'data/AFEW/raw-audios/train/',
#                                     'duration': 3,
#                                     'format': '.mp3',
#                                     'is_train': True,
#                                     'n_mels': 128,
#                                     'sr': 22050},
#                           'loader': { 'args': { 'batch_size': 4,
#                                                 'drop_last': False,
#                                                 'shuffle': True},
#                                       'name': 'DataLoader'},
#                           'name': 'AudioDataset'},
#                'val': { 'args': { 'csv_path': 'data/AFEW/raw-audios/val.csv',
#                                   'data_dir': 'data/AFEW/raw-audios/val/',
#                                   'duration': 3,
#                                   'format': '.mp3',
#                                   'is_train': False,
#                                   'n_mels': 128,
#                                   'sr': 22050},
#                         'loader': { 'args': {'batch_size': 4, 'shuffle': True},
#                                     'name': 'DataLoader'},
#                         'name': 'AudioDataset'}},
#   'debug': False,
#   'gpus': '0',
#   'id': 'audio_effnet_b0',
#   'loss': {'args': None, 'name': 'CrossEntropyLoss'},
#   'metric': [{'args': None, 'name': 'Accuracy'}],
#   'model': { 'args': { 'freeze_backbone': False,
#                        'from_pretrained': True,
#                        'name': 'tf_efficientnet_b0_ns',
#                        'num_classes': 3},
#              'name': 'BaseTimmModel'},
#   'optimizer': {'args': {'lr': 0.0001}, 'name': 'Adam'},
#   'pretrained': None,
#   'scheduler': { 'args': {'gamma': 0.2, 'last_epoch': -1, 'step_size': 3},
#                  'name': 'StepLR'},
#   'trainer': {'log_step': 1, 'nepochs': 5, 'val_step': 1}}
#
# Epoch   0
# -----------------------------------
# Training........
# 100%|█████████████████████████████████████████| 107/107 [02:45<00:00,  1.55s/it]
# + Training result
# Loss: 1.0845879767542688
# Accuracy: 0.37704917788505554
# Evaluating........
# 100%|███████████████████████████████████████████| 48/48 [01:07<00:00,  1.41s/it]
# + Evaluation result
# Loss: 1.0609801126023135
# Accuracy: 0.44736844301223755
# -----------------------------------
# Loss is improved from  inf to  1.060980. Saving weights...
# Accuracy is improved from  0.000000 to  0.447368. Saving weights...
#
# Epoch   1
# -----------------------------------
# Training........
# 100%|█████████████████████████████████████████| 107/107 [02:53<00:00,  1.62s/it]
# + Training result
# Loss: 0.9761291658766917
# Accuracy: 0.5597189664840698
# Evaluating........
# 100%|███████████████████████████████████████████| 48/48 [01:13<00:00,  1.53s/it]
# + Evaluation result
# Loss: 1.0383809233705197
# Accuracy: 0.4526315927505493
# -----------------------------------
# Loss is improved from  1.060980 to  1.038381. Saving weights...
# Accuracy is improved from  0.447368 to  0.452632. Saving weights...
#
# Epoch   2
# -----------------------------------
# Training........
# 100%|█████████████████████████████████████████| 107/107 [03:20<00:00,  1.87s/it]
# + Training result
# Loss: 0.8871536767371349
# Accuracy: 0.6229507923126221
# Evaluating........
# 100%|███████████████████████████████████████████| 48/48 [01:11<00:00,  1.50s/it]
# + Evaluation result
# Loss: 0.9985883856813114
# Accuracy: 0.5210526585578918
# -----------------------------------
# Loss is improved from  1.038381 to  0.998588. Saving weights...
# Accuracy is improved from  0.452632 to  0.521053. Saving weights...
#
# Epoch   3
# -----------------------------------
# Training........
# 100%|█████████████████████████████████████████| 107/107 [03:05<00:00,  1.74s/it]
# + Training result
# Loss: 0.7233187358513055
# Accuracy: 0.7283372282981873
# Evaluating........
# 100%|███████████████████████████████████████████| 48/48 [01:12<00:00,  1.50s/it]
# + Evaluation result
# Loss: 1.0957319748898346
# Accuracy: 0.46315792202949524
# -----------------------------------
# Loss is not improved from 0.998588.
# Accuracy is not improved from 0.521053.
#
# Epoch   4
# -----------------------------------
# Training........
#   4%|█▌                                         | 4/107 [00:08<03:18,  1.93s/it]^C
#   4%|█▌                                         | 4/107 [00:08<03:40,  2.14s/it]
# Traceback (most recent call last):
#   File "/home/kvu/erc/venv/lib/python3.6/site-packages/librosa/core/audio.py", line 146, in load
#     with sf.SoundFile(path) as sf_desc:
#   File "/home/kvu/erc/venv/lib/python3.6/site-packages/soundfile.py", line 629, in __init__
#     self._file = self._open(file, mode_int, closefd)
#   File "/home/kvu/erc/venv/lib/python3.6/site-packages/soundfile.py", line 1184, in _open
#     "Error opening {0!r}: ".format(self.name))
#   File "/home/kvu/erc/venv/lib/python3.6/site-packages/soundfile.py", line 1357, in _error_check
#     raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
# RuntimeError: Error opening 'data/AFEW/raw-audios/train/001414094.mp3': File contains data in an unknown format.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "train.py", line 120, in <module>
#     train(config)
#   File "train.py", line 93, in train
#     val_dataloader=val_dataloader)
#   File "./libs/workers/trainer.py", line 178, in train
#     self.train_epoch(epoch=epoch, dataloader=train_dataloader)
#   File "./libs/workers/trainer.py", line 87, in train_epoch
#     for i, (inp, lbl) in enumerate(progress_bar):
#   File "/home/kvu/erc/venv/lib/python3.6/site-packages/tqdm/std.py", line 1170, in __iter__
#     for obj in iterable:
#   File "/home/kvu/erc/venv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 435, in __next__
#     data = self._next_data()
#   File "/home/kvu/erc/venv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 475, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/home/kvu/erc/venv/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/kvu/erc/venv/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py", line 44, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "./libs/datasets/audio.py", line 66, in __getitem__
#     y = self.get_audio(audio_path_w_format)
#   File "./libs/datasets/audio.py", line 25, in get_audio
#     y, _ = lb.load(audio_path, sr=self.sr, duration=self.duration, offset=offset)
#   File "/home/kvu/erc/venv/lib/python3.6/site-packages/librosa/core/audio.py", line 163, in load
#     y, sr_native = __audioread_load(path, offset, duration, dtype)
#   File "/home/kvu/erc/venv/lib/python3.6/site-packages/librosa/core/audio.py", line 187, in __audioread_load
#     with audioread.audio_open(path) as input_file:
#   File "/home/kvu/erc/venv/lib/python3.6/site-packages/audioread/__init__.py", line 107, in audio_open
#     backends = available_backends()
#   File "/home/kvu/erc/venv/lib/python3.6/site-packages/audioread/__init__.py", line 71, in available_backends
#     if _ca_available():
#   File "/home/kvu/erc/venv/lib/python3.6/site-packages/audioread/__init__.py", line 49, in _ca_available
#     lib = ctypes.util.find_library('AudioToolbox')
#   File "/usr/lib/python3.6/ctypes/util.py", line 314, in find_library
#     _get_soname(_findLib_gcc(name) or _findLib_ld(name))
#   File "/usr/lib/python3.6/ctypes/util.py", line 302, in _findLib_ld
#     universal_newlines=True)
#   File "/usr/lib/python3.6/subprocess.py", line 729, in __init__
#     restore_signals, start_new_session)
#   File "/usr/lib/python3.6/subprocess.py", line 1295, in _execute_child
#     restore_signals, start_new_session, preexec_fn)
# KeyboardInterrupt
