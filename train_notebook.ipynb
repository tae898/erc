# %%
# !nvidia-smi
# Out:
# Sat Apr 17 21:07:47 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1050    Off  | 00000000:01:00.0 Off |                  N/A |
# | N/A   52C    P0    N/A /  N/A |   1403MiB /  4042MiB |     15%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1153      G   /usr/lib/xorg/Xorg                199MiB |
# |    0   N/A  N/A      1721      G   /usr/bin/gnome-shell               33MiB |
# |    0   N/A  N/A      3297      G   ...AAAAAAAA== --shared-files       35MiB |
# |    0   N/A  N/A      3843      G   ...AAAAAAAAA= --shared-files      100MiB |
# |    0   N/A  N/A     45805      C   .../kvu/erc/venv/bin/python3     1031MiB |
# +-----------------------------------------------------------------------------+

# %%
# !rm -rf runs/

# %%
# !python3 train.py --config configs/context_aware.yaml --gpus 0
# Out:
# { 'dataset': { 'train': { 'args': { 'audio_feat_dir': 'Datasets/MELD/audio-features/train/',
#                                     'csv_path': 'data/raw-audios-wav/train.csv',
#                                     'dataset': 'train',
#                                     'num_utt': 2,
#                                     'ordered_json_list': 'Datasets/MELD/utterance-ordered.json',
#                                     'text_feat_dir': 'Datasets/MELD/text-features/train/'},
#                           'loader': { 'args': { 'batch_size': 8,
#                                                 'drop_last': True,
#                                                 'shuffle': True},
#                                       'name': 'DataLoader'},
#                           'name': 'ContextAwareDataset'},
#                'val': { 'args': { 'audio_feat_dir': 'Datasets/MELD/audio-features/val/',
#                                   'csv_path': 'data/raw-audios-wav/val.csv',
#                                   'dataset': 'val',
#                                   'num_utt': 2,
#                                   'ordered_json_list': 'Datasets/MELD/utterance-ordered.json',
#                                   'text_feat_dir': 'Datasets/MELD/text-features/val/'},
#                         'loader': { 'args': { 'batch_size': 8,
#                                               'drop_last': True,
#                                               'shuffle': True},
#                                     'name': 'DataLoader'},
#                         'name': 'ContextAwareDataset'}},
#   'debug': False,
#   'gpus': '0',
#   'id': 'context_aware_multimodal_fusion',
#   'loss': { 'args': {'alpha': 0.75, 'gamma': 2, 'reduce': True},
#             'name': 'FocalLoss'},
#   'metric': [{'args': None, 'name': 'F1Weighted'}],
#   'model': {'args': {'num_classes': 7}, 'name': 'ContextAwareModel'},
#   'optimizer': {'args': {'lr': 0.0001}, 'name': 'Adam'},
#   'pretrained': None,
#   'scheduler': { 'args': {'gamma': 0.2, 'last_epoch': -1, 'step_size': 2},
#                  'name': 'StepLR'},
#   'trainer': {'log_step': 1, 'nepochs': 20, 'val_step': 1}}
#
# Epoch   0
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:50<00:00,  5.42it/s]
# + Training result
# Loss: 0.548261667291323
# F1 weighted: 0.4881122032376843
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:03<00:00, 38.58it/s]
# + Evaluation result
# Loss: 0.5365951876830907
# F1 weighted: 0.5157264577732661
# -----------------------------------
# Loss is improved from  inf to  0.536595. Saving weights...
# F1Weighted is improved from  0.000000 to  0.515726. Saving weights...
#
# Epoch   1
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:52<00:00,  5.37it/s]
# + Training result
# Loss: 0.37868336866216484
# F1 weighted: 0.6412221723178708
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:03<00:00, 34.67it/s]
# + Evaluation result
# Loss: 0.5228942594578674
# F1 weighted: 0.5939840372210121
# -----------------------------------
# Loss is improved from  0.536595 to  0.522894. Saving weights...
# F1Weighted is improved from  0.515726 to  0.593984. Saving weights...
#
# Epoch   2
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:58<00:00,  5.24it/s]
# + Training result
# Loss: 0.33547278875014935
# F1 weighted: 0.6824777416096319
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:03<00:00, 35.70it/s]
# + Evaluation result
# Loss: 0.46226260919407347
# F1 weighted: 0.6183005346349789
# -----------------------------------
# Loss is improved from  0.522894 to  0.462263. Saving weights...
# F1Weighted is improved from  0.593984 to  0.618301. Saving weights...
#
# Epoch   3
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:54<00:00,  5.32it/s]
# + Training result
# Loss: 0.30302368206489133
# F1 weighted: 0.7021503652807674
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:03<00:00, 41.76it/s]
# + Evaluation result
# Loss: 0.4784786715509665
# F1 weighted: 0.6235446943996162
# -----------------------------------
# Loss is not improved from 0.462263.
# F1Weighted is improved from  0.618301 to  0.623545. Saving weights...
#
# Epoch   4
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:34<00:00,  5.81it/s]
# + Training result
# Loss: 0.2941072094718734
# F1 weighted: 0.7110193955566345
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:04<00:00, 34.13it/s]
# + Evaluation result
# Loss: 0.47604296689826064
# F1 weighted: 0.6196538514368798
# -----------------------------------
# Loss is not improved from 0.462263.
# F1Weighted is not improved from 0.623545.
#
# Epoch   5
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [04:04<00:00,  5.11it/s]
# + Training result
# Loss: 0.282693632415127
# F1 weighted: 0.7226005349949605
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:03<00:00, 36.74it/s]
# + Evaluation result
# Loss: 0.49142851584516745
# F1 weighted: 0.6238656865473258
# -----------------------------------
# Loss is not improved from 0.462263.
# F1Weighted is improved from  0.623545 to  0.623866. Saving weights...
#
# Epoch   6
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [04:02<00:00,  5.15it/s]
# + Training result
# Loss: 0.28142867544253614
# F1 weighted: 0.724316768190661
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:03<00:00, 41.86it/s]
# + Evaluation result
# Loss: 0.5007761389968675
# F1 weighted: 0.6096141176783209
# -----------------------------------
# Loss is not improved from 0.462263.
# F1Weighted is not improved from 0.623866.
#
# Epoch   7
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:49<00:00,  5.43it/s]
# + Training result
# Loss: 0.2727148819905825
# F1 weighted: 0.7264436599955958
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:03<00:00, 35.25it/s]
# + Evaluation result
# Loss: 0.41599316151974636
# F1 weighted: 0.6260338451126829
# -----------------------------------
# Loss is improved from  0.462263 to  0.415993. Saving weights...
# F1Weighted is improved from  0.623866 to  0.626034. Saving weights...
#
# Epoch   8
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:52<00:00,  5.36it/s]
# + Training result
# Loss: 0.2670331308127533
# F1 weighted: 0.728063262702681
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:03<00:00, 42.05it/s]
# + Evaluation result
# Loss: 0.4359560244433259
# F1 weighted: 0.6207863423323177
# -----------------------------------
# Loss is not improved from 0.415993.
# F1Weighted is not improved from 0.626034.
#
# Epoch   9
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:38<00:00,  5.72it/s]
# + Training result
# Loss: 0.26498780365494484
# F1 weighted: 0.7293040630377673
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:04<00:00, 34.10it/s]
# + Evaluation result
# Loss: 0.4322675728691283
# F1 weighted: 0.6275905332146743
# -----------------------------------
# Loss is not improved from 0.415993.
# F1Weighted is improved from  0.626034 to  0.627591. Saving weights...
#
# Epoch  10
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:47<00:00,  5.48it/s]
# + Training result
# Loss: 0.25720619304355297
# F1 weighted: 0.733591471631559
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:03<00:00, 43.47it/s]
# + Evaluation result
# Loss: 0.44040832225827214
# F1 weighted: 0.6279579134616897
# -----------------------------------
# Loss is not improved from 0.415993.
# F1Weighted is improved from  0.627591 to  0.627958. Saving weights...
#
# Epoch  11
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:31<00:00,  5.91it/s]
# + Training result
# Loss: 0.2619589954865656
# F1 weighted: 0.734118172192618
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:03<00:00, 36.86it/s]
# + Evaluation result
# Loss: 0.4432098603186509
# F1 weighted: 0.6333257822213594
# -----------------------------------
# Loss is not improved from 0.415993.
# F1Weighted is improved from  0.627958 to  0.633326. Saving weights...
#
# Epoch  12
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:38<00:00,  5.72it/s]
# + Training result
# Loss: 0.2509477329964655
# F1 weighted: 0.7339432222113109
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:03<00:00, 37.70it/s]
# + Evaluation result
# Loss: 0.5217188027133978
# F1 weighted: 0.6148936896777583
# -----------------------------------
# Loss is not improved from 0.415993.
# F1Weighted is not improved from 0.633326.
#
# Epoch  13
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:42<00:00,  5.61it/s]
# + Training result
# Loss: 0.25142243604419445
# F1 weighted: 0.7394001847337369
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:03<00:00, 39.57it/s]
# + Evaluation result
# Loss: 0.45676393252358755
# F1 weighted: 0.6275267555944104
# -----------------------------------
# Loss is not improved from 0.415993.
# F1Weighted is not improved from 0.633326.
#
# Epoch  14
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:43<00:00,  5.59it/s]
# + Training result
# Loss: 0.24551436307620667
# F1 weighted: 0.7423169716378751
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:04<00:00, 33.32it/s]
# + Evaluation result
# Loss: 0.45157992711503303
# F1 weighted: 0.6308770494970527
# -----------------------------------
# Loss is not improved from 0.415993.
# F1Weighted is not improved from 0.633326.
#
# Epoch  15
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [04:06<00:00,  5.05it/s]
# + Training result
# Loss: 0.24155842467902966
# F1 weighted: 0.7427448296941176
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:03<00:00, 35.45it/s]
# + Evaluation result
# Loss: 0.4714317721237962
# F1 weighted: 0.6284083071584428
# -----------------------------------
# Loss is not improved from 0.415993.
# F1Weighted is not improved from 0.633326.
#
# Epoch  16
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:53<00:00,  5.35it/s]
# + Training result
# Loss: 0.24384448930001026
# F1 weighted: 0.7442906697044994
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:04<00:00, 33.33it/s]
# + Evaluation result
# Loss: 0.4718942032735524
# F1 weighted: 0.6225339214161418
# -----------------------------------
# Loss is not improved from 0.415993.
# F1Weighted is not improved from 0.633326.
#
# Epoch  17
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:53<00:00,  5.34it/s]
# + Training result
# Loss: 0.23506446812172774
# F1 weighted: 0.7454967623990246
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:03<00:00, 43.07it/s]
# + Evaluation result
# Loss: 0.47765372579991544
# F1 weighted: 0.6267265329576206
# -----------------------------------
# Loss is not improved from 0.415993.
# F1Weighted is not improved from 0.633326.
#
# Epoch  18
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:38<00:00,  5.70it/s]
# + Training result
# Loss: 0.22932811336525075
# F1 weighted: 0.7495121841162788
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:03<00:00, 42.70it/s]
# + Evaluation result
# Loss: 0.4788236534096422
# F1 weighted: 0.6392363398256699
# -----------------------------------
# Loss is not improved from 0.415993.
# F1Weighted is improved from  0.633326 to  0.639236. Saving weights...
#
# Epoch  19
# -----------------------------------
# Training........
# 100%|███████████████████████████████████████| 1248/1248 [03:47<00:00,  5.49it/s]
# + Training result
# Loss: 0.23084987890848804
# F1 weighted: 0.7535049010148129
# Evaluating........
# 100%|█████████████████████████████████████████| 138/138 [00:03<00:00, 39.16it/s]
# + Evaluation result
# Loss: 0.44586556135133526
# F1 weighted: 0.6334756628612515
# -----------------------------------
# Loss is not improved from 0.415993.
# F1Weighted is not improved from 0.639236.

# %% [markdown]
# ## Tensorboard

# %%
# %load_ext tensorboard
# %reload_ext tensorboard

# %%
# %tensorboard --logdir=runs/
# Out:
# Reusing TensorBoard on port 6006 (pid 24815), started 5:05:16 ago. (Use '!kill 24815' to kill it.)
#       <iframe id="tensorboard-frame-8c4c2da40124a571" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8c4c2da40124a571");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
