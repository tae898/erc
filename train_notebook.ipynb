# %%
# !nvidia-smi
# Out:
# Tue Feb 23 23:11:29 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.102.04   Driver Version: 450.102.04   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1050    Off  | 00000000:01:00.0 Off |                  N/A |
# | N/A   44C    P3    N/A /  N/A |    664MiB /  4042MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1330      G   /usr/lib/xorg/Xorg                 80MiB |
# |    0   N/A  N/A      2073      G   /usr/lib/xorg/Xorg                164MiB |
# |    0   N/A  N/A      2255      G   /usr/bin/gnome-shell              134MiB |
# |    0   N/A  N/A      3897      G   ...AAAAAAAAA= --shared-files      180MiB |
# |    0   N/A  N/A      6288      G   ...AAAAAAAA== --shared-files       95MiB |
# +-----------------------------------------------------------------------------+

# %%
# import timm
# from pprint import pprint
# model_names = timm.list_models(pretrained=True)
# pprint(model_names)

# %%
# !python3 train.py --config configs/audio_effnet.yaml --gpus 0
# Out:
# { 'dataset': { 'train': { 'args': { 'csv_path': 'data/AFEW/raw-audios/train.csv',
#                                     'data_dir': 'data/AFEW/raw-audios/train/',
#                                     'duration': 3,
#                                     'format': '.mp3',
#                                     'is_train': True,
#                                     'n_mels': 128,
#                                     'sr': 22050},
#                           'loader': { 'args': { 'batch_size': 4,
#                                                 'drop_last': False,
#                                                 'shuffle': True},
#                                       'name': 'DataLoader'},
#                           'name': 'AudioDataset'},
#                'val': { 'args': { 'csv_path': 'data/AFEW/raw-audios/val.csv',
#                                   'data_dir': 'data/AFEW/raw-audios/val/',
#                                   'duration': 3,
#                                   'format': '.mp3',
#                                   'is_train': False,
#                                   'n_mels': 128,
#                                   'sr': 22050},
#                         'loader': { 'args': {'batch_size': 4, 'shuffle': True},
#                                     'name': 'DataLoader'},
#                         'name': 'AudioDataset'}},
#   'debug': False,
#   'gpus': '0',
#   'id': 'audio_effnet_b0',
#   'loss': {'args': None, 'name': 'FocalLoss'},
#   'metric': [{'args': None, 'name': 'Accuracy'}],
#   'model': { 'args': { 'freeze_backbone': False,
#                        'from_pretrained': True,
#                        'name': 'tf_efficientnet_b3_ns',
#                        'num_classes': 3},
#              'name': 'BaseTimmModel'},
#   'optimizer': {'args': {'lr': 0.0001}, 'name': 'Adam'},
#   'pretrained': None,
#   'scheduler': { 'args': {'gamma': 0.2, 'last_epoch': -1, 'step_size': 3},
#                  'name': 'StepLR'},
#   'trainer': {'log_step': 1, 'nepochs': 10, 'val_step': 1}}
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/tf_efficientnet_b3_ns-9d44bf68.pth" to /home/kvu/.cache/torch/hub/checkpoints/tf_efficientnet_b3_ns-9d44bf68.pth
#
# Epoch   0
# -----------------------------------
# Training........
# 100%|█████████████████████████████████████████| 107/107 [03:20<00:00,  1.87s/it]
# + Training result
# Loss: 1.1440805436294772
# Accuracy: 0.34660419821739197
# Evaluating........
# 100%|███████████████████████████████████████████| 48/48 [01:14<00:00,  1.55s/it]
# + Evaluation result
# Loss: 1.0966632738709448
# Accuracy: 0.4105263352394104
# -----------------------------------
# Loss is improved from  inf to  1.096663. Saving weights...
# Accuracy is improved from  0.000000 to  0.410526. Saving weights...
#
# Epoch   1
# -----------------------------------
# Training........
# 100%|█████████████████████████████████████████| 107/107 [02:49<00:00,  1.58s/it]
# + Training result
# Loss: 1.017336389728796
# Accuracy: 0.5081967115402222
# Evaluating........
# 100%|███████████████████████████████████████████| 48/48 [01:09<00:00,  1.45s/it]
# + Evaluation result
# Loss: 1.1192571359376113
# Accuracy: 0.40526318550109863
# -----------------------------------
# Loss is not improved from 1.096663.
# Accuracy is not improved from 0.410526.
#
# Epoch   2
# -----------------------------------
# Training........
# 100%|█████████████████████████████████████████| 107/107 [02:57<00:00,  1.66s/it]
# + Training result
# Loss: 0.9424702096208233
# Accuracy: 0.5503512620925903
# Evaluating........
# 100%|███████████████████████████████████████████| 48/48 [01:06<00:00,  1.39s/it]
# + Evaluation result
# Loss: 1.049343309054772
# Accuracy: 0.4578947424888611
# -----------------------------------
# Loss is improved from  1.096663 to  1.049343. Saving weights...
# Accuracy is improved from  0.410526 to  0.457895. Saving weights...
#
# Epoch   3
# -----------------------------------
# Training........
# 100%|█████████████████████████████████████████| 107/107 [02:56<00:00,  1.65s/it]
# + Training result
# Loss: 0.8297532763436576
# Accuracy: 0.6323184967041016
# Evaluating........
# 100%|███████████████████████████████████████████| 48/48 [01:09<00:00,  1.44s/it]
# + Evaluation result
# Loss: 1.0798179085055988
# Accuracy: 0.4421052932739258
# -----------------------------------
# Loss is not improved from 1.049343.
# Accuracy is not improved from 0.457895.
#
# Epoch   4
# -----------------------------------
# Training........
# 100%|█████████████████████████████████████████| 107/107 [03:03<00:00,  1.71s/it]
# + Training result
# Loss: 0.7857698231378448
# Accuracy: 0.6627634167671204
# Evaluating........
# 100%|███████████████████████████████████████████| 48/48 [01:18<00:00,  1.63s/it]
# + Evaluation result
# Loss: 1.0580110580970838
# Accuracy: 0.5052632093429565
# -----------------------------------
# Loss is not improved from 1.049343.
# Accuracy is improved from  0.457895 to  0.505263. Saving weights...
#
# Epoch   5
# -----------------------------------
# Training........
# 100%|█████████████████████████████████████████| 107/107 [03:18<00:00,  1.86s/it]
# + Training result
# Loss: 0.5911170678021753
# Accuracy: 0.7704917788505554
# Evaluating........
# 100%|███████████████████████████████████████████| 48/48 [01:16<00:00,  1.59s/it]
# + Evaluation result
# Loss: 1.1397163247068722
# Accuracy: 0.47894740104675293
# -----------------------------------
# Loss is not improved from 1.049343.
# Accuracy is not improved from 0.505263.
#
# Epoch   6
# -----------------------------------
# Training........
# 100%|█████████████████████████████████████████| 107/107 [02:47<00:00,  1.57s/it]
# + Training result
# Loss: 0.5274798095783341
# Accuracy: 0.7915690541267395
# Evaluating........
# 100%|███████████████████████████████████████████| 48/48 [01:04<00:00,  1.34s/it]
# + Evaluation result
# Loss: 1.1209784767900903
# Accuracy: 0.5105263590812683
# -----------------------------------
# Loss is not improved from 1.049343.
# Accuracy is improved from  0.505263 to  0.510526. Saving weights...
#
# Epoch   7
# -----------------------------------
# Training........
# 100%|█████████████████████████████████████████| 107/107 [02:39<00:00,  1.49s/it]
# + Training result
# Loss: 0.4518737127987024
# Accuracy: 0.8313816785812378
# Evaluating........
# 100%|███████████████████████████████████████████| 48/48 [01:03<00:00,  1.33s/it]
# + Evaluation result
# Loss: 1.2108653330554564
# Accuracy: 0.48947370052337646
# -----------------------------------
# Loss is not improved from 1.049343.
# Accuracy is not improved from 0.510526.
#
# Epoch   8
# -----------------------------------
# Training........
# 100%|█████████████████████████████████████████| 107/107 [02:39<00:00,  1.49s/it]
# + Training result
# Loss: 0.41983339103443607
# Accuracy: 0.845433235168457
# Evaluating........
# 100%|███████████████████████████████████████████| 48/48 [01:04<00:00,  1.35s/it]
# + Evaluation result
# Loss: 1.3149526494865622
# Accuracy: 0.4736842215061188
# -----------------------------------
# Loss is not improved from 1.049343.
# Accuracy is not improved from 0.510526.
#
# Epoch   9
# -----------------------------------
# Training........
# 100%|█████████████████████████████████████████| 107/107 [02:38<00:00,  1.48s/it]
# + Training result
# Loss: 0.41414868716742387
# Accuracy: 0.8384074568748474
# Evaluating........
# 100%|███████████████████████████████████████████| 48/48 [01:04<00:00,  1.35s/it]
# + Evaluation result
# Loss: 1.4603713427980745
# Accuracy: 0.42105263471603394
# -----------------------------------
# Loss is not improved from 1.049343.
# Accuracy is not improved from 0.510526.

# %% [markdown]
# ## Tensorboard

# %%
# %load_ext tensorboard
# %reload_ext tensorboard

# %%
# %tensorboard --logdir=runs/
# Out:
#       <iframe id="tensorboard-frame-dcc4344ce5365734" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-dcc4344ce5365734");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
