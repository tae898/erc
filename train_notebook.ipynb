# %%
# !nvidia-smi
# Out:
# Mon Apr 12 19:27:30 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1050    Off  | 00000000:01:00.0 Off |                  N/A |
# | N/A   54C    P0    N/A /  N/A |    401MiB /  4042MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1049      G   /usr/lib/xorg/Xorg                173MiB |
# |    0   N/A  N/A      1590      G   /usr/bin/gnome-shell               57MiB |
# |    0   N/A  N/A      3143      G   ...AAAAAAAAA= --shared-files      127MiB |
# |    0   N/A  N/A     15101      G   ...AAAAAAAA== --shared-files       40MiB |
# +-----------------------------------------------------------------------------+

# %%
# !rm -rf runs/

# %%
# !python3 train.py --config configs/multimodal_single.yaml --gpus 0
# Out:
# { 'dataset': { 'train': { 'args': { 'audio_feat_dir': 'Datasets/MELD/audio-features/train/',
#                                     'csv_path': 'data/raw-audios-wav/train.csv',
#                                     'text_feat_dir': 'Datasets/MELD/text-features/train/'},
#                           'loader': { 'args': { 'batch_size': 8,
#                                                 'drop_last': True,
#                                                 'shuffle': True},
#                                       'name': 'DataLoader'},
#                           'name': 'AudioTextFeatureVectorDataset'},
#                'val': { 'args': { 'audio_feat_dir': 'Datasets/MELD/audio-features/val/',
#                                   'csv_path': 'data/raw-audios-wav/val.csv',
#                                   'text_feat_dir': 'Datasets/MELD/text-features/val/'},
#                         'loader': { 'args': { 'batch_size': 8,
#                                               'drop_last': True,
#                                               'shuffle': True},
#                                     'name': 'DataLoader'},
#                         'name': 'AudioTextFeatureVectorDataset'}},
#   'debug': False,
#   'gpus': '0',
#   'id': 'single_utterance_multimodal_fusion',
#   'loss': { 'args': {'alpha': 0.75, 'gamma': 3, 'reduce': True},
#             'name': 'FocalLoss'},
#   'metric': [{'args': None, 'name': 'F1Weighted'}],
#   'model': {'args': {'num_classes': 7}, 'name': 'FusionModel'},
#   'optimizer': {'args': {'lr': 1e-05}, 'name': 'Adam'},
#   'pretrained': None,
#   'scheduler': { 'args': {'factor': 0.1, 'patience': 5},
#                  'name': 'ReduceLROnPlateau'},
#   'trainer': {'log_step': 1, 'nepochs': 20, 'val_step': 1}}
#
# Epoch   0
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 118.01it/s]
# + Training result
# Loss: 0.25028888414875916
# F1 weighted: 0.6842616830415122
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 184.94it/s]
# + Evaluation result
# Loss: 0.28453179333861767
# F1 weighted: 0.63175029678843
# -----------------------------------
# Loss is improved from  inf to  0.284532. Saving weights...
# F1Weighted is improved from  0.000000 to  0.631750. Saving weights...
#
# Epoch   1
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 122.25it/s]
# + Training result
# Loss: 0.15709546089187124
# F1 weighted: 0.7367845105018923
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 187.95it/s]
# + Evaluation result
# Loss: 0.29811475631794404
# F1 weighted: 0.6335528495765198
# -----------------------------------
# Loss is not improved from 0.284532.
# F1Weighted is improved from  0.631750 to  0.633553. Saving weights...
#
# Epoch   2
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 122.71it/s]
# + Training result
# Loss: 0.1484816863716016
# F1 weighted: 0.7399544186283584
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 194.53it/s]
# + Evaluation result
# Loss: 0.27499471580697404
# F1 weighted: 0.6367249495514198
# -----------------------------------
# Loss is improved from  0.284532 to  0.274995. Saving weights...
# F1Weighted is improved from  0.633553 to  0.636725. Saving weights...
#
# Epoch   3
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 123.46it/s]
# + Training result
# Loss: 0.13417120095627033
# F1 weighted: 0.7484670010544554
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 194.19it/s]
# + Evaluation result
# Loss: 0.2647495143844381
# F1 weighted: 0.639645431952542
# -----------------------------------
# Loss is improved from  0.274995 to  0.264750. Saving weights...
# F1Weighted is improved from  0.636725 to  0.639645. Saving weights...
#
# Epoch   4
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 121.78it/s]
# + Training result
# Loss: 0.13153373785284067
# F1 weighted: 0.7538121416289825
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 178.60it/s]
# + Evaluation result
# Loss: 0.2723403658947326
# F1 weighted: 0.6418879786666064
# -----------------------------------
# Loss is not improved from 0.264750.
# F1Weighted is improved from  0.639645 to  0.641888. Saving weights...
#
# Epoch   5
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 123.45it/s]
# + Training result
# Loss: 0.12705297775377966
# F1 weighted: 0.7527425203258157
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 179.05it/s]
# + Evaluation result
# Loss: 0.2689693186556975
# F1 weighted: 0.6460990817838999
# -----------------------------------
# Loss is not improved from 0.264750.
# F1Weighted is improved from  0.641888 to  0.646099. Saving weights...
#
# Epoch   6
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 120.29it/s]
# + Training result
# Loss: 0.12518250465435798
# F1 weighted: 0.7596287097179687
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 166.09it/s]
# + Evaluation result
# Loss: 0.27057372655785306
# F1 weighted: 0.6377311120122454
# -----------------------------------
# Loss is not improved from 0.264750.
# F1Weighted is not improved from 0.646099.
#
# Epoch   7
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 123.04it/s]
# + Training result
# Loss: 0.119760722788576
# F1 weighted: 0.7595320796083869
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 192.05it/s]
# + Evaluation result
# Loss: 0.26713427531775896
# F1 weighted: 0.6372870696608887
# -----------------------------------
# Loss is not improved from 0.264750.
# F1Weighted is not improved from 0.646099.
#
# Epoch   8
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 118.23it/s]
# + Training result
# Loss: 0.11730572541096203
# F1 weighted: 0.7662806452468107
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 165.79it/s]
# + Evaluation result
# Loss: 0.25667610324149875
# F1 weighted: 0.6416779521361424
# -----------------------------------
# Loss is improved from  0.264750 to  0.256676. Saving weights...
# F1Weighted is not improved from 0.646099.
#
# Epoch   9
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 115.00it/s]
# + Training result
# Loss: 0.1152083987285666
# F1 weighted: 0.7656064166952427
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 191.99it/s]
# + Evaluation result
# Loss: 0.2725545009994623
# F1 weighted: 0.6355793582492565
# -----------------------------------
# Loss is not improved from 0.256676.
# F1Weighted is not improved from 0.646099.
#
# Epoch  10
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 114.86it/s]
# + Training result
# Loss: 0.11393473703934336
# F1 weighted: 0.7687738128185374
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 183.10it/s]
# + Evaluation result
# Loss: 0.27903878773730056
# F1 weighted: 0.6360500931089866
# -----------------------------------
# Loss is not improved from 0.256676.
# F1Weighted is not improved from 0.646099.
#
# Epoch  11
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 120.24it/s]
# + Training result
# Loss: 0.11270699201891608
# F1 weighted: 0.765016247440899
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 191.66it/s]
# + Evaluation result
# Loss: 0.27400932489747554
# F1 weighted: 0.6354698811461553
# -----------------------------------
# Loss is not improved from 0.256676.
# F1Weighted is not improved from 0.646099.
#
# Epoch  12
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 118.22it/s]
# + Training result
# Loss: 0.10454404352972578
# F1 weighted: 0.7700831734953747
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 193.04it/s]
# + Evaluation result
# Loss: 0.28504619248965557
# F1 weighted: 0.6376596144873442
# -----------------------------------
# Loss is not improved from 0.256676.
# F1Weighted is not improved from 0.646099.
#
# Epoch  13
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 122.23it/s]
# + Training result
# Loss: 0.1058429060597735
# F1 weighted: 0.7749581384073879
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 194.84it/s]
# + Evaluation result
# Loss: 0.2622538847339245
# F1 weighted: 0.6506100344447148
# -----------------------------------
# Loss is not improved from 0.256676.
# F1Weighted is improved from  0.646099 to  0.650610. Saving weights...
#
# Epoch  14
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 122.63it/s]
# + Training result
# Loss: 0.10337908942398578
# F1 weighted: 0.7705461974306922
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 186.46it/s]
# + Evaluation result
# Loss: 0.3035688182795453
# F1 weighted: 0.6399589667673473
# -----------------------------------
# Loss is not improved from 0.256676.
# F1Weighted is not improved from 0.650610.
#
# Epoch  15
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 120.32it/s]
# + Training result
# Loss: 0.09916404911186824
# F1 weighted: 0.7794183930737798
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 188.04it/s]
# + Evaluation result
# Loss: 0.28886326180772676
# F1 weighted: 0.6350457595359026
# -----------------------------------
# Loss is not improved from 0.256676.
# F1Weighted is not improved from 0.650610.
#
# Epoch  16
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 121.59it/s]
# + Training result
# Loss: 0.10024692250771612
# F1 weighted: 0.7771050844428733
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 187.29it/s]
# + Evaluation result
# Loss: 0.26782296571637626
# F1 weighted: 0.6368722730888172
# -----------------------------------
# Loss is not improved from 0.256676.
# F1Weighted is not improved from 0.650610.
#
# Epoch  17
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 119.65it/s]
# + Training result
# Loss: 0.09935681340891446
# F1 weighted: 0.781137777438307
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 191.67it/s]
# + Evaluation result
# Loss: 0.28098136431725684
# F1 weighted: 0.6373444553723665
# -----------------------------------
# Loss is not improved from 0.256676.
# F1Weighted is not improved from 0.650610.
#
# Epoch  18
# -----------------------------------
# Training........
# 100%|██████████████████████████████████████| 1248/1248 [00:10<00:00, 121.70it/s]
# + Training result
# Loss: 0.09744377287119012
# F1 weighted: 0.7807899673865091
# Evaluating........
# 100%|████████████████████████████████████████| 138/138 [00:00<00:00, 185.14it/s]
# + Evaluation result
# Loss: 0.2771302354272137
# F1 weighted: 0.6374878347206758
# -----------------------------------
# Loss is not improved from 0.256676.
# F1Weighted is not improved from 0.650610.
#
# Epoch  19
# -----------------------------------
# Training........
#  95%|████████████████████████████████████  | 1184/1248 [00:09<00:00, 121.39it/s]

# %% [markdown]
# ## Tensorboard

# %%
# %load_ext tensorboard
# %reload_ext tensorboard

# %%
# %tensorboard --logdir=runs/
