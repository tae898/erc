# %%
from glob import glob
import json
import pprint

def read_json(path):
    with open(path, 'r') as stream:
        foo = json.load(stream)
    
    foo = {key:val for key, val in foo.items() if key in ['DATASET', 'eval_loss', 'num_past_utterances', 'num_future_utterances', 'speaker_mode']}

    return foo

def parse_path(path):
    splits = path.split('/')
    DATASET = splits[0]
    roberta = splits[1]
    hp_details = splits[2].split('-')
    speaker_mode = hp_details[7]
    assert speaker_mode in ['upper', 'None', 'title']
    num_past_utterances = int(hp_details[9])
    num_future_utterances = int(hp_details[11])
    
    return {'DATASET': DATASET, 'roberta': roberta, 'speaker_mode': speaker_mode, 'num_past_utterances': num_past_utterances, 'num_future_utterances':num_future_utterances}

def merge_two_dicts(a, b):
    c = {}
    for key, val in a.items():
        c[key] = val
    for key, val in b.items():
        c[key] = val
        
    return c

def return_sorted(hp_results, DATASET, roberta):
    to_return = [foo for foo in hp_results if foo['DATASET'] == DATASET and foo['roberta'] == roberta]
    
    to_return = sorted(to_return, key=lambda k:k['eval_loss'])
    
    return to_return
    

hp_results = glob('*/*/*/val-results.json')
hp_results = [(parse_path(path), read_json(path)) for path in hp_results]
hp_results = [merge_two_dicts(foo[0], foo[1]) for foo in hp_results]


top_k = 5
roberta = 'roberta-base'
for DATASET in ['MELD', 'IEMOCAP', 'EmoryNLP', 'DailyDialog']:
    stats = return_sorted(hp_results, DATASET, roberta)[:top_k]    
    
    print('----------------------------------------')
    pprint.pprint([stat for stat in stats])
    print('----------------------------------------')
# Out:
# ----------------------------------------
# [{'DATASET': 'MELD',
#   'eval_loss': 1.2951059341430664,
#   'num_future_utterances': 0,
#   'num_past_utterances': 2,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'upper'},
#  {'DATASET': 'MELD',
#   'eval_loss': 1.2972556352615356,
#   'num_future_utterances': 0,
#   'num_past_utterances': 8,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'upper'},
#  {'DATASET': 'MELD',
#   'eval_loss': 1.3212463855743408,
#   'num_future_utterances': 2,
#   'num_past_utterances': 0,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'title'},
#  {'DATASET': 'MELD',
#   'eval_loss': 1.3212932348251343,
#   'num_future_utterances': 0,
#   'num_past_utterances': 4,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'upper'},
#  {'DATASET': 'MELD',
#   'eval_loss': 1.3371278047561646,
#   'num_future_utterances': 0,
#   'num_past_utterances': 0,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'None'}]
# ----------------------------------------
# ----------------------------------------
# [{'DATASET': 'IEMOCAP',
#   'eval_loss': 0.9510225653648376,
#   'num_future_utterances': 8,
#   'num_past_utterances': 8,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'upper'},
#  {'DATASET': 'IEMOCAP',
#   'eval_loss': 0.9651377201080322,
#   'num_future_utterances': 4,
#   'num_past_utterances': 4,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'upper'},
#  {'DATASET': 'IEMOCAP',
#   'eval_loss': 1.0071192979812622,
#   'num_future_utterances': 16,
#   'num_past_utterances': 16,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'upper'},
#  {'DATASET': 'IEMOCAP',
#   'eval_loss': 1.01212477684021,
#   'num_future_utterances': 32,
#   'num_past_utterances': 32,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'upper'},
#  {'DATASET': 'IEMOCAP',
#   'eval_loss': 1.0190848112106323,
#   'num_future_utterances': 2,
#   'num_past_utterances': 2,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'title'}]
# ----------------------------------------
# ----------------------------------------
# [{'DATASET': 'EmoryNLP',
#   'eval_loss': 1.6537355184555054,
#   'num_future_utterances': 0,
#   'num_past_utterances': 0,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'None'},
#  {'DATASET': 'EmoryNLP',
#   'eval_loss': 1.6560602188110352,
#   'num_future_utterances': 0,
#   'num_past_utterances': 1,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'None'},
#  {'DATASET': 'EmoryNLP',
#   'eval_loss': 1.6587024927139282,
#   'num_future_utterances': 0,
#   'num_past_utterances': 0,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'upper'},
#  {'DATASET': 'EmoryNLP',
#   'eval_loss': 1.6647984981536865,
#   'num_future_utterances': 1,
#   'num_past_utterances': 0,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'title'},
#  {'DATASET': 'EmoryNLP',
#   'eval_loss': 1.675121545791626,
#   'num_future_utterances': 0,
#   'num_past_utterances': 2,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'upper'}]
# ----------------------------------------
# ----------------------------------------
# [{'DATASET': 'DailyDialog',
#   'eval_loss': 0.39094749093055725,
#   'num_future_utterances': 0,
#   'num_past_utterances': 0,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'upper'},
#  {'DATASET': 'DailyDialog',
#   'eval_loss': 0.3944404125213623,
#   'num_future_utterances': 1,
#   'num_past_utterances': 1,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'upper'},
#  {'DATASET': 'DailyDialog',
#   'eval_loss': 0.39495810866355896,
#   'num_future_utterances': 0,
#   'num_past_utterances': 0,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'None'},
#  {'DATASET': 'DailyDialog',
#   'eval_loss': 0.4046725332736969,
#   'num_future_utterances': 0,
#   'num_past_utterances': 1,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'upper'},
#  {'DATASET': 'DailyDialog',
#   'eval_loss': 0.41032326221466064,
#   'num_future_utterances': 1,
#   'num_past_utterances': 1,
#   'roberta': 'roberta-base',
#   'speaker_mode': 'title'}]
# ----------------------------------------
